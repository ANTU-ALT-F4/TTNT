# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12007, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 12007 (delta 7), reused 9 (delta 3), pack-reused 11984
# Receiving objects: 100% (12007/12007), 12.53 MiB | 14.29 MiB/s, done.
# Resolving deltas: 100% (8246/8246), done.

# %%
# %cd /content/yolov5/
# !pip install -qr requirements.txt
# Out:
# /content/yolov5

# %%
# !python detect.py --source /content/car-g66d23a21d_640.jpg --weights yolov5s.pt --conf 0.8 --name demo --exist-ok
# Out:
# detect: weights=['yolov5s.pt'], source=/content/car-g66d23a21d_640.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=demo, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-57-gf2b8f3f Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/car-g66d23a21d_640.jpg: 448x640 2 cars, 13.0ms
# Speed: 0.5ms pre-process, 13.0ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/demo

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/yolov5/runs/detect/demo/car-g66d23a21d_640.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x426 at 0x7F1760309790>

# %%
# !python detect.py --source /content/animals-cats-cute-45170-min.jpg --weights yolov5s.pt --conf 0.8 --name demo --exist-ok
# Out:
# detect: weights=['yolov5s.pt'], source=/content/animals-cats-cute-45170-min.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=demo, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-57-gf2b8f3f Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/animals-cats-cute-45170-min.jpg: 384x640 1 cat, 14.8ms
# Speed: 0.4ms pre-process, 14.8ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/demo

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/yolov5/runs/detect/demo/animals-cats-cute-45170-min.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x667 at 0x7F176031A2D0>
